# %% [markdown]
# # Baseline BM25 Experiment
#
# Use this notebook to test the first retrieval baseline against the Swiss legal data.
#
# Start by loading the raw CSV files from `data/raw/` and building a simple BM25 index over the legal texts.

# %%
from pathlib import Path

import pandas as pd

from src.config import LAWS_FILE, TEST_FILE
from src.data_loader import load_dataset
from src.retriever import BM25Retriever

laws_df = load_dataset(LAWS_FILE)
test_df = load_dataset(TEST_FILE)

laws_df.head(), test_df.head()
